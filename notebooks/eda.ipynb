# %%
# notebooks/eda.ipynb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset - gunakan raw string atau forward slash
df = pd.read_excel(r"C:/Users/arel/Documents/Bootcamp/Project/ecommerce_data_pipeline/datasets/online_retail.xlsx")

# Atau lebih baik: gunakan path relative
# df = pd.read_excel("../datasets/online_retail.xlsx")

# cek 5 data teratas
print("First 5 rows:")
print(df.head())

# info dataset
print("\nDataset info:")
print(df.info())

# cek missing values
print("\nMissing values:")
print(df.isnull().sum())

# basic statistics
print("\nDescriptive statistics:")
print(df.describe())

# cek unique values
print("\nUnique values per column:")
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# First 5 rows:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
# ...
